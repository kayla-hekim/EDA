# %% [markdown]
# # Assignment: Exploratory Data Analysis
# ### `! git clone https://github.com/ds4e/EDA`
# ### Do Q1 and two other questions.

# %% [markdown]
# **Q1.** In class, we talked about how to compute the sample mean of a variable $X$,
# $$
# m(X) = \dfrac{1}{N} \sum_{i=1}^N x_i
# $$
# and sample covariance of two variables $X$ and $Y$,
# $$
# \text{cov}(X,Y) = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(y_i - m(Y))).
# $$
# Recall, the sample variance of $X$ is
# $$
# s^2 = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))^2.
# $$
# It can be very helpful to understand some basic properties of these statistics. If you want to write your calculations on a piece of paper, take a photo, and upload that to your GitHub repo, that's probably easiest.
#
# 1. Show that $m(a + bX) = a+b \times m(X)$.
#    ![title](img/1.png)
# 2. Show that $\text{cov}(X,a+bY) = b \times \text{cov}(X,Y)$
#    ![title](img/2.png)
# 3. Show that $\text{cov}(a+bX,a+bX) = b^2 \text{cov}(X,X) $, and in particular that $\text{cov}(X,X) = s^2 $.
#    ![title](img/3.png)
# 4. Instead of the mean, consider the median. Consider transformations that are non-decreasing (if $x\ge x'$, then $g(x)\ge g(x')$), like $2+5 \times X$ or $\text{arcsinh}(X)$. Is a non-decreasing transformation of the median the median of the transformed variable? Explain. Does your answer apply to any quantile? The IQR? The range?
#     * In terms of the median, the median doesn't always satisfy g(Median(X)) = Median(g(X)). This is because the median depends on where the new middle of the dataset is. In this case, if we did g(x) = x^2, the set {1 2 3} because {1 4 9}, where the median is 4, not 2 like in the original set. The mean is slightly more "resistant" to this trend because it's the average of the values, not a new center value. Other transformations could cause other effects.
#     * In terms of quantiles, a quantile evaluates the position of values in relation to each other. Because of this, the quantile is not affected by changes in order under a non-decreasing transformation. But, the actual value of the quantile can change due to the transformation, similar to the median.
#     * Like the median, the IQR is not resistant to the non-decreasing transformations. Like in the g(x) = x^2 example, if we squared {1, 2, 3}, we would get {1, 4, 9} which increases the distance from median 4 to the Q1 and Q3 values, modifying the IQR range. This happens because transformations like squaring affect the spacing between values differently across the dataset.
#     * The range is not resistant to the non-decreasing transformations because we could take that same example of g(x) = x^2 where the set goes from {1, 2, 3} to {1, 4, 9}. The range of the first set is 2 while the range of the second is 8 which is different. This shows that the range is affected by the transformation and is not preserved.
# 5. Consider a non-decreasing transformation $g()$. Is is always true that $m(g(X))= g(m(X))$?
#    * The mean of g(X) is not always resistant to the transformation because of its value. If we took the average of {1, 2, 3}, we receive (1 + 2 + 3)/3 = 2, but {1, 4, 9} would be (1 + 4 + 9)/3 = 4.67. This shows that the mean is not preserved under non-decreasing transformations because the factors changed. The mean changes under transformation since the values change in a non-linear way, modifying the resulting average.

# %% [markdown]
# **Q2.** This question looks at financial transfers from foreign entities to American universities. In particular, from which countries and gifters are the gifts coming from, and to which institutions are they going? For this question, `.groupby([vars]).count()` and `.groupby([vars]).sum()` will be especially useful to tally the number of occurrences and sum the values of those occurrences.
#
# 1. Load the `./data/ForeignGifts_edu.csv` dataset.
# 2. For `Foreign Gift Amount`, create a histogram and describe the variable. Describe your findings.
# 3. For `Gift Type`, create a histogram or value counts table. What proportion of the gifts are contracts, real estate, and monetary gifts?
# 4. Create a kernel density plot of the log of `Foreign Gift Amount`, and then a kernel density plot of the log of `Foreign Gift Amount` conditional on gift type. Do you notice any patterns?
# 5. What are the top 15 countries in terms of the number of gifts? What are the top 15 countries in terms of the amount given?
# 6. What are the top 15 institutions in terms of the total amount of money they receive? Make a histogram of the total amount received by all institutions.
# 7. Which giftors provide the most money, in total?

# %% [markdown]
# **Q3.** This question uses the Airbnb data to practice making visualizations.
#
#   1. Load the `./data/airbnb_hw.csv` data with Pandas. This provides a dataset of AirBnB rental properties for New York City.
#   2. What are are the dimensions of the data? How many observations are there? What are the variables included? Use `.head()` to examine the first few rows of data.
#   3. Cross tabulate `Room Type` and `Property Type`. What patterns do you see in what kinds of rentals are available? For which kinds of properties are private rooms more common than renting the entire property?
#   4. For `Price`, make a histogram, kernel density, box plot, and a statistical description of the variable. Are the data badly scaled? Are there many outliers? Use `log` to transform price into a new variable, `price_log`, and take these steps again.
#   5. Make a scatterplot of `price_log` and `Beds`. Describe what you see. Use `.groupby()` to compute a desciption of `Price` conditional on/grouped by the number of beds. Describe any patterns you see in the average price and standard deviation in prices.
#   6. Make a scatterplot of `price_log` and `Beds`, but color the graph by `Room Type` and `Property Type`. What patterns do you see? Compute a description of `Price` conditional on `Room Type` and `Property Type`. Which Room Type and Property Type have the highest prices on average? Which have the highest standard deviation? Does the mean or median appear to be a more reliable estimate of central tendency, and explain why?
#   7. We've looked a bit at this `price_log` and `Beds` scatterplot. Use seaborn to make a `jointplot` with `kind=hex`. Where are the data actually distributed? How does it affect the way you think about the plots in 5 and 6?

# %%
#1.
import pandas as pd
import numpy as np
airbnb_df = pd.read_csv('data/airbnb_hw.csv', header=0)
print("#1. \nUploaded the airbnb_hw.csv file and stored it in a variable called airbnb_df. \n\n")


# #2.
print("#2.")
print("It appears there's", str(airbnb_df.shape[0]), "rows and", str(airbnb_df.shape[1]), "columns for the dimension. \n")
print("There are", airbnb_df.shape[0], "observations. \n")
print("Here are the variables included:")
for i in range(len(airbnb_df.columns)):
    print(str(i+1) + ". " + str( airbnb_df.columns[i]))
print("\nHead information look:\n", airbnb_df.head())
print("\n")


#3.
print("#3.")
print(pd.crosstab(airbnb_df['Room Type'], airbnb_df['Property Type'], margins=True))
print("Rentals available are entire home/apt, private room, and shared room.")
print("Properties more common to Private rooms than to entire home/apt include bed&breakfasts, dorms, houses, huts, other, tents, and treehouses.")
print("\n")


#4. 
import matplotlib.pyplot as plt
import seaborn as sns
print("#4.")
airbnb_df['Price'] = pd.to_numeric(airbnb_df['Price'], errors='coerce')
# histogram:
plt.hist(airbnb_df['Price'], bins=16, color='blue', alpha=0.7)
plt.show()
# KDE:
sns.kdeplot(airbnb_df["Price"].dropna(), bw_adjust=0.5)
plt.show()
# boxplot:
sns.boxplot(x=airbnb_df['Price'].dropna())
plt.show()
# statistical summary:
airbnb_df['Price'].describe()
print("Based on the plots and the statistical information, it appears that the data is badly scaled because the range of the values is incredibly large. \nThe max is 999 while the min is 10, and the mean is around 153. This tells me that the data is incredibly right skewed and that there may be outliers affecting \nthis skew. The charts support this theory because they all have a right tail, especially seen in the boxplot.")

# WITH LOG:
price_log = airbnb_df['Price'].apply(lambda x: np.log(x))
plt.hist(price_log, bins=16, color='blue', alpha=0.7)
plt.show()
# KDE:
sns.kdeplot(price_log, bw_adjust=0.5)
plt.show()
# boxplot:
sns.boxplot(x=price_log)
plt.show()
# statistical summary:
price_log.describe()
print("Now it seems the data is more normalized and non-right skewed. \nThis is based on the mean being almost equidistant to the max and min and the plots showing this 'normal' distribution. \n\n")


#5. 
print("#5.")
plt.scatter(price_log, airbnb_df['Beds'])
print("I see pretty straight horizontal lines as if a bar plot across the graph. This may indicate that the number of beds is a categorical or almost discrete variable.")

mean_group =  airbnb_df.groupby('Beds')['Price'].agg('mean')
std_group =  airbnb_df.groupby('Beds')['Price'].agg('std')
# plt.scatter(mean_group, std_group)
print(mean_group, "\n\n", std_group)
print("In the mean, I see that the mean generally increases steadily until the 9 point. At this point, the mean slightly decreases until the 12th point. \nThe data then jumps from 12 to 16 to which it has almost a 2x increase. In the Standard deviation, it follows a similar general trend. \nWhen I graphed mean by std, the trend appears to resemble a line but there's a mean of around 600 that displays an outlier.\n\n")


#6. 
print("#6.")
airbnb_df['price_log'] = price_log
sns.scatterplot(data=airbnb_df, x="price_log", y="Beds", hue="Room Type", alpha=0.7)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
print("There appears to be more expensive entire home/apt rentals, then private rooms, and then in shared rooms. \nThis might be because the more space you rent, the more expensive the property becomes to rent.\n")
sns.scatterplot(data=airbnb_df, x="price_log", y="Beds", hue="Property Type", alpha=0.7)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
print("There appears to be a lot of apartments, houses,and castles/chalets (surprisingly). However, their distribution is varied in terms of price, \nsome being highly expensive, others relatively cheaper. The outdoor properties appear to have a relatively middle ground for price range out of all prices.\n")
print("For both Rent and Property Type, the amount of beds increases as the space increases for each property. \nFor example, houses and apartments have more beds compared to that of a shared room.\n\n")


#7. 
print("#7.")
sns.jointplot(data=airbnb_df, x="price_log", y="Beds", kind="hex")
plt.show()
print("With the new information showing that the data is skewed for both beds (only a few units with more than 5 beds) \nand price_log (a couple outliers on the more expensive side), I can see that the 2 graphs from earlier had the impression that most of the airbnb \nunits were highly expensive or that there were a lot more beds per unit. I now see that the distribution is highlighted towards a middle point for both, \nbut that the outliers were misleading the human eye.")
# Out:
# #1.
# Uploaded the airbnb_hw.csv file and stored it in a variable called airbnb_df.
#
#
# #2.
# It appears there's 30478 rows and 13 columns for the dimension.
#
# There are 30478 observations.
#
# Here are the variables included:
# 1. Host Id
# 2. Host Since
# 3. Name
# 4. Neighbourhood
# 5. Property Type
# 6. Review Scores Rating (bin)
# 7. Room Type
# 8. Zipcode
# 9. Beds
# 10. Number of Records
# 11. Number Of Reviews
# 12. Price
# 13. Review Scores Rating
#
# Head information look:
#      Host Id Host Since                                Name Neighbourhood   \
# 0   5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626        NaN                Sunny Room in Harlem      Manhattan
# 3       500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  6/26/2008            Trendy Times Square Loft      Manhattan
#
# ...

# %% [markdown]
# **Q4.** This question looks at a time series of the number of active oil drilling rigs in the United States over time. The data comes from the Energy Information Agency.
#
# 1. Load `./data/drilling_rigs.csv` and examine the data. How many observations? How many variables? Are numeric variables correctly read in by Pandas, or will some variables have to be typecast/coerced? Explain clearly how these data need to be cleaned.
# 2. To convert the `Month` variable to an ordered datetime variable, use `df['time'] = pd.to_datetime(df['Month'], format='mixed')`.
# 3. Let's look at `Active Well Service Rig Count (Number of Rigs)`, which is the total number of rigs over time. Make a line plot of this time series. Describe what you see.
# 4. Instead of levels, we want to look at change over time. Compute the first difference of  `Active Well Service Rig Count (Number of Rigs)` and plot it over time. Describe what you see.
# 5. The first two columns are the number of onshore and offshore rigs, respectively. Melt these columns and plot the resulting series.
